# %%
operacoes = ["adição","Subtração","Multiplicação","Divisão"]
operacao = ""
print("olá Usuário. bem vindo a calculadora Interativa")
print("")
print("Defina a operação que pretende utilizar")
print("")
print("Adição  -  Subtração -  Multiplicação  -  Divisão")
print("")
operacao = input()
if (operacao == operacoes[0]):
    print("Digite o valor da parcela 1 e parcela 2.")
    valor1 = input()
    valor2 = input()
    resultado = (int(valor1) + int(valor2))
    print("O parcela 1 é = ", valor1)
    print("O parcela 2 é = ", valor2)
    print("o resultado é: ", resultado)
if (operacao == operacoes[1]):
    print("Digite o valor do Minuendo e Subtraendo.")
    valor1 = input()
    valor2 = input()
    resultado = (int(valor1) - int(valor2))
    print("O Minuendo 1 é = ", valor1)
    print("O Subtraendo 2 é = ", valor2)
    print("o resultado é: ", resultado)
if (operacao == operacoes[2]):
    print("Digite o valor do fator 1 e fator 2.")
    valor1 = input()
    valor2 = input()
    resultado = (int(valor1) * int(valor2))
    print("O fator 1 é = ", valor1)
    print("O fator 2 é = ", valor2)
    print("o resultado é: ", resultado)
if (operacao == operacoes[3]):
    print("Digite o valor do Dividendo e Divisor.")
    valor1 = input()
    valor2 = input()
    resultado = (int(valor1) / int(valor2))
    resto = (int(valor1) % int(valor2))
    print("O Dividendo é = ", valor1)
    print("O Divisor é = ", valor2)
    print("o resultado é: ", resultado)
    print("o resto é: ", resto)
# Out:
# olá Usuário. bem vindo a calculadora Interativa
#
# Defina a operação que pretende utilizar
#
# Adição  -  Subtração -  Multiplicação  -  Divisão
#
# Subtração
# Digite o valor da Minuendo 1 e Subtraendo 2

# %%
if (operacao == operacoes[1]):
    valor1 = input()
    valor2 = input()
    resultado = (int(valor1) + int(valor2))
    print(resultado)
